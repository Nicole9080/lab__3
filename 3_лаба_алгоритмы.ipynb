# %% [markdown]
# <a href="https://colab.research.google.com/github/Nicole9080/lab__3/blob/main/3_%D0%BB%D0%B0%D0%B1%D0%B0_%D0%B0%D0%BB%D0%B3%D0%BE%D1%80%D0%B8%D1%82%D0%BC%D1%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Реализуйте функцию insertion_sort_float(arr), которая сортирует список чисел с плавающей точкой (float) методом вставок.

def insertion_sort_float(arr):
    for i in range(1, len(arr)):
        current = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > current:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = current

a = [1.1, 0.9, 1.2]
insertion_sort_float(a)
print(a)
# Out:
# [0.9, 1.1, 1.2]
